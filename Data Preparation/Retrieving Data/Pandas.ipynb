# %%
import numpy as np
import pandas as pd

# %%
# Reads data from excel
df = pd.read_excel('TCP_2021_data_FINAL.xlsx', sheet_name='Sheet1')
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-10d992573a2c> in <cell line: 2>()
#       1 # Reads data from excel
# ----> 2 df = pd.read_excel('TCP_2021_data_FINAL.xlsx', sheet_name='Sheet1')
#       3 df.head(5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# Converts pandas dataframe to numpy arrays
featureNames = df.columns.values
data = df['Average Peak Download Speed (Mbps)'].values
data = df[['City', 'Average Peak Download Speed (Mbps)']].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5b472dd65a14> in <cell line: 2>()
#       1 # Converts pandas dataframe to numpy arrays
# ----> 2 featureNames = df.columns.values
#       3 data = df['Average Peak Download Speed (Mbps)'].values
#       4 data = df[['City', 'Average Peak Download Speed (Mbps)']].values
#
# NameError: name 'df' is not defined
